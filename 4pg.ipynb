# %%
import pandas as pd
def find_s_algorithm(file_path):
    data=pd.read_csv(file_path)
    print("Training Data:")
    print(data)
    attributes=data.columns[:-1]
    class_label=data.columns[-1]
    hypothesis=['?' for _ in attributes]
    for index, row in data.iterrows():
        if row[class_label]=='Yes':
            for i, value in enumerate(row[attributes]):
                if hypothesis[i]=='?' or hypothesis[i]==value:
                    hypothesis[i]=value
                else:
                    hypothesis[i]='?'
    return hypothesis
file_path='training_data_new.csv'
hypothesis=find_s_algorithm(file_path)
print("\nThe final hypothsis is:",hypothesis)
# Out:
# Training Data:
#   Outlook Airtemp Humidity    Wind Water Forecast Enjoyspot
# 0   Sunny    Warm     High  Strong  Warm     Same       Yes
# 1   Rainy    Cold     High  Strong  Warm   Change        No
# 2   Sunny    Warm     High  Strong  Cool   Change       Yes
# 3   Rainy    Cold   Normal  Strong  Cool     Same        No
#
# The final hypothsis is: ['Sunny', 'Warm', 'High', 'Strong', '?', '?']
